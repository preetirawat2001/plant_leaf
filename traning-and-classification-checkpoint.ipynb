# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## Download and explore the dataset

# %%
import pathlib
data_dir = "leaf_photos"
data_dir = pathlib.Path(data_dir)

# %% [markdown]
# now have a copy of the dataset available.

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 5178

# %% [markdown]
# Here are some bactrial spot:

# %%
bacterial_spots = list(data_dir.glob('Tomato_Bacterial_Spot/*'))
PIL.Image.open(str(bacterial_spots[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
PIL.Image.open(str(bacterial_spots[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %% [markdown]
# And some healthy:

# %%
healthys = list(data_dir.glob('Tomato_Healthy/*'))
PIL.Image.open(str(healthys[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
PIL.Image.open(str(healthys[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %% [markdown]
# # Load using keras.preprocessing
#
# Let's load these images off disk using the helpful [image_dataset_from_directory](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory) utility. This will take you from a directory of images on disk to a `tf.data.Dataset` in just a couple lines of code. If you like, you can also write your own data loading code from scratch by visiting the [load images](https://www.tensorflow.org/tutorials/load_data/images) tutorial.

# %% [markdown]
# ## Create a dataset

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# It's good practice to use a validation split when developing your model. Let's use 80% of the images for training, and 20% for validation.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 5178 files belonging to 13 classes.
# Using 4143 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 5178 files belonging to 13 classes.
# Using 1035 files for validation.

# %% [markdown]
# You can find the class names in the `class_names` attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___healthy', 'Tomato_Bacterial_Spot', 'Tomato_Early_Blight', 'Tomato_Healthy', 'Tomato_Leaf_mold', 'Tomato_Septorial_Leaf_Spot', 'Tomato_Yellow_Leaf_Curl_Virus']

# %% [markdown]
# ## Visualize the data
#
# Here are the first 9 images from the training dataset.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# ## Configure the dataset for performance
#
# Let's make sure to use buffered prefetching so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data.
#
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standardize the data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network; in general you should seek to make your input values small. Here, you will standardize values to be in the `[0, 1]` range by using a Rescaling layer.

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %% [markdown]
# Note: The Keras Preprocessing utilities and layers introduced in this section are currently experimental and may change.

# %% [markdown]
# There are two ways to use this layer. You can apply it to the dataset by calling map:

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.7299013

# %% [markdown]
# # Create the model
#
# The model consists of three convolution blocks with a max pool layer in each of them. There's a fully connected layer with 128 units on top of it that is activated by a `relu` activation function. This model has not been tuned for high accuracy, the goal of this tutorial is to show a standard approach.

# %%
num_classes = 13

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Compile the model
#
# For this tutorial, choose the `optimizers.Adam` optimizer and `losses.SparseCategoricalCrossentropy` loss function. To view training and validation accuracy for each training epoch, pass the `metrics` argument.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Model summary
#
# View all the layers of the network using the model's `summary` method:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 13)                1677
# =================================================================
# Total params: 3,990,317
# Trainable params: 3,990,317
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model
# entire processing by the learning algorithm of the entire train-set. The MNIST train set

# %%
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 130/130 [==============================] - 46s 348ms/step - loss: 1.8068 - accuracy: 0.3864 - val_loss: 0.7247 - val_accuracy: 0.7662
# Epoch 2/30
# 130/130 [==============================] - 40s 306ms/step - loss: 0.6196 - accuracy: 0.7916 - val_loss: 0.5609 - val_accuracy: 0.8203
# Epoch 3/30
# 130/130 [==============================] - 40s 308ms/step - loss: 0.3475 - accuracy: 0.8882 - val_loss: 0.5607 - val_accuracy: 0.8338
# Epoch 4/30
# 130/130 [==============================] - 41s 313ms/step - loss: 0.2069 - accuracy: 0.9333 - val_loss: 0.4099 - val_accuracy: 0.8705
# Epoch 5/30
# 130/130 [==============================] - 40s 304ms/step - loss: 0.1471 - accuracy: 0.9565 - val_loss: 0.6822 - val_accuracy: 0.8145
# Epoch 6/30
# 130/130 [==============================] - 38s 296ms/step - loss: 0.1485 - accuracy: 0.9510 - val_loss: 0.4412 - val_accuracy: 0.8870
# Epoch 7/30
# 130/130 [==============================] - 39s 300ms/step - loss: 0.0762 - accuracy: 0.9744 - val_loss: 0.5289 - val_accuracy: 0.8792
# Epoch 8/30
# 130/130 [==============================] - 39s 299ms/step - loss: 0.0425 - accuracy: 0.9860 - val_loss: 0.5071 - val_accuracy: 0.8705
# Epoch 9/30
# 130/130 [==============================] - 39s 297ms/step - loss: 0.0794 - accuracy: 0.9703 - val_loss: 0.6229 - val_accuracy: 0.8618
# Epoch 10/30
# 130/130 [==============================] - 39s 301ms/step - loss: 0.0450 - accuracy: 0.9869 - val_loss: 0.5289 - val_accuracy: 0.8715
# Epoch 11/30
# 130/130 [==============================] - 39s 302ms/step - loss: 0.0265 - accuracy: 0.9930 - val_loss: 0.5591 - val_accuracy: 0.8850
# Epoch 12/30
# 130/130 [==============================] - 43s 332ms/step - loss: 0.0069 - accuracy: 0.9991 - val_loss: 0.5461 - val_accuracy: 0.8725
# Epoch 13/30
# 130/130 [==============================] - 36s 279ms/step - loss: 0.0168 - accuracy: 0.9937 - val_loss: 0.8358 - val_accuracy: 0.8348
# Epoch 14/30
# 130/130 [==============================] - 37s 281ms/step - loss: 0.0659 - accuracy: 0.9753 - val_loss: 0.5629 - val_accuracy: 0.8802
# Epoch 15/30
# 130/130 [==============================] - 37s 283ms/step - loss: 0.0152 - accuracy: 0.9952 - val_loss: 0.6011 - val_accuracy: 0.8763
# Epoch 16/30
# 130/130 [==============================] - 36s 277ms/step - loss: 0.0156 - accuracy: 0.9936 - val_loss: 0.5954 - val_accuracy: 0.8928
# Epoch 17/30
# 130/130 [==============================] - 36s 279ms/step - loss: 0.0047 - accuracy: 0.9994 - val_loss: 0.5753 - val_accuracy: 0.9063
# Epoch 18/30
# 130/130 [==============================] - 37s 288ms/step - loss: 3.2689e-04 - accuracy: 1.0000 - val_loss: 0.5959 - val_accuracy: 0.9101
# Epoch 19/30
# 130/130 [==============================] - 38s 293ms/step - loss: 2.2443e-04 - accuracy: 1.0000 - val_loss: 0.6041 - val_accuracy: 0.9082
# Epoch 20/30
# 130/130 [==============================] - 43s 332ms/step - loss: 1.3151e-04 - accuracy: 1.0000 - val_loss: 0.6173 - val_accuracy: 0.9101
# Epoch 21/30
# 130/130 [==============================] - 38s 294ms/step - loss: 1.4074e-04 - accuracy: 1.0000 - val_loss: 0.6272 - val_accuracy: 0.9121
# Epoch 22/30
# 130/130 [==============================] - 38s 292ms/step - loss: 1.0059e-04 - accuracy: 1.0000 - val_loss: 0.6311 - val_accuracy: 0.9121
# Epoch 23/30
# 130/130 [==============================] - 37s 285ms/step - loss: 9.1176e-05 - accuracy: 1.0000 - val_loss: 0.6389 - val_accuracy: 0.9121
# Epoch 24/30
# 130/130 [==============================] - 37s 281ms/step - loss: 7.8423e-05 - accuracy: 1.0000 - val_loss: 0.6478 - val_accuracy: 0.9130
# Epoch 25/30
# 130/130 [==============================] - 38s 291ms/step - loss: 7.5174e-05 - accuracy: 1.0000 - val_loss: 0.6547 - val_accuracy: 0.9130
# Epoch 26/30
# 130/130 [==============================] - 38s 290ms/step - loss: 5.5098e-05 - accuracy: 1.0000 - val_loss: 0.6605 - val_accuracy: 0.9140
# Epoch 27/30
# 130/130 [==============================] - 38s 294ms/step - loss: 5.4212e-05 - accuracy: 1.0000 - val_loss: 0.6655 - val_accuracy: 0.9130
# Epoch 28/30
# 130/130 [==============================] - 39s 297ms/step - loss: 4.6502e-05 - accuracy: 1.0000 - val_loss: 0.6733 - val_accuracy: 0.9130
# Epoch 29/30
# 130/130 [==============================] - 38s 289ms/step - loss: 4.5976e-05 - accuracy: 1.0000 - val_loss: 0.6759 - val_accuracy: 0.9130
# Epoch 30/30
# 130/130 [==============================] - 37s 286ms/step - loss: 3.6523e-05 - accuracy: 1.0000 - val_loss: 0.6813 - val_accuracy: 0.9140

# %% [markdown]
# ## Visualize training results

# %% [markdown]
# Create plots of loss and accuracy on the training and validation sets.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# As you can see from the plots, training accuracy and validation accuracy are off by large margin and the model has achieved only around 60% accuracy on the validation set.
#
# Let's look at what went wrong and try to increase the overall performance of the model.

# %% [markdown]
# ## Overfitting

# %% [markdown]
# In the plots above, the training accuracy is increasing linearly over time, whereas validation accuracy stalls around 60% in the training process. Also, the difference in accuracy between training and validation accuracy is noticeable—a sign of [overfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit).
#
# When there are a small number of training examples, the model sometimes learns from noises or unwanted details from training examples—to an extent that it negatively impacts the performance of the model on new examples. This phenomenon is known as overfitting. It means that the model will have a difficult time generalizing on a new dataset.
#
# There are multiple ways to fight overfitting in the training process. In this tutorial, you'll use *data augmentation* and add *Dropout* to your model.

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# Overfitting generally occurs when there are a small number of training examples. [Data augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation) takes the approach of generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.
#
# You will implement data augmentation using experimental [Keras Preprocessing Layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/?version=nightly). These can be included inside your model like other layers, and run on the GPU.

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Let's visualize what a few augmented examples look like by applying data augmentation to the same image several times:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# You will use data augmentation to train a model in a moment.

# %% [markdown]
# ## Dropout
#
# Another technique to reduce overfitting is to introduce [Dropout](https://developers.google.com/machine-learning/glossary#dropout_regularization) to the network, a form of *regularization*.
#
# When you apply Dropout to a layer it randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.
#
# Let's create a new neural network using `layers.Dropout`, then train it using augmented images.

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_1 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_2 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dense_3 (Dense)              (None, 13)                1677
# =================================================================
# Total params: 3,990,317
# Trainable params: 3,990,317
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 130/130 [==============================] - 43s 330ms/step - loss: 1.7488 - accuracy: 0.3940 - val_loss: 0.9993 - val_accuracy: 0.6783
# Epoch 2/50
# 130/130 [==============================] - 43s 331ms/step - loss: 0.8180 - accuracy: 0.7331 - val_loss: 0.8439 - val_accuracy: 0.7150
# Epoch 3/50
# 130/130 [==============================] - 51s 392ms/step - loss: 0.6035 - accuracy: 0.8036 - val_loss: 1.1187 - val_accuracy: 0.6918
# Epoch 4/50
# 130/130 [==============================] - 62s 480ms/step - loss: 0.4610 - accuracy: 0.8506 - val_loss: 0.6369 - val_accuracy: 0.8048
# Epoch 5/50
# 130/130 [==============================] - 60s 458ms/step - loss: 0.3426 - accuracy: 0.8971 - val_loss: 0.6070 - val_accuracy: 0.8039
# Epoch 6/50
# 130/130 [==============================] - 58s 446ms/step - loss: 0.3107 - accuracy: 0.8987 - val_loss: 0.6917 - val_accuracy: 0.8087
# Epoch 7/50
# 130/130 [==============================] - 58s 446ms/step - loss: 0.3267 - accuracy: 0.8926 - val_loss: 0.3561 - val_accuracy: 0.8947
# Epoch 8/50
# 130/130 [==============================] - 313s 2s/step - loss: 0.2210 - accuracy: 0.9362 - val_loss: 0.5750 - val_accuracy: 0.8193
# Epoch 9/50
# 130/130 [==============================] - 48s 367ms/step - loss: 0.2212 - accuracy: 0.9230 - val_loss: 1.1000 - val_accuracy: 0.7227
# Epoch 10/50
# 130/130 [==============================] - 42s 320ms/step - loss: 0.1914 - accuracy: 0.9372 - val_loss: 0.3426 - val_accuracy: 0.8937
# Epoch 11/50
# 130/130 [==============================] - 42s 323ms/step - loss: 0.1771 - accuracy: 0.9388 - val_loss: 0.2879 - val_accuracy: 0.9014
# Epoch 12/50
# 130/130 [==============================] - 42s 320ms/step - loss: 0.1396 - accuracy: 0.9561 - val_loss: 0.8291 - val_accuracy: 0.7807
# Epoch 13/50
# 130/130 [==============================] - 42s 321ms/step - loss: 0.1766 - accuracy: 0.9398 - val_loss: 0.2921 - val_accuracy: 0.9169
# Epoch 14/50
# 130/130 [==============================] - 42s 323ms/step - loss: 0.1759 - accuracy: 0.9439 - val_loss: 0.2870 - val_accuracy: 0.9121
# Epoch 15/50
# 130/130 [==============================] - 42s 321ms/step - loss: 0.1523 - accuracy: 0.9484 - val_loss: 0.2088 - val_accuracy: 0.9362
# Epoch 16/50
# 130/130 [==============================] - 46s 353ms/step - loss: 0.1251 - accuracy: 0.9554 - val_loss: 0.2622 - val_accuracy: 0.9179
# Epoch 17/50
# 130/130 [==============================] - 58s 446ms/step - loss: 0.1794 - accuracy: 0.9407 - val_loss: 0.4083 - val_accuracy: 0.8889
# Epoch 18/50
# 130/130 [==============================] - 58s 447ms/step - loss: 0.1368 - accuracy: 0.9549 - val_loss: 0.2013 - val_accuracy: 0.9430
# Epoch 19/50
# 130/130 [==============================] - 58s 448ms/step - loss: 0.0995 - accuracy: 0.9689 - val_loss: 0.3053 - val_accuracy: 0.9111
# Epoch 20/50
# 130/130 [==============================] - 58s 447ms/step - loss: 0.0815 - accuracy: 0.9710 - val_loss: 0.3044 - val_accuracy: 0.9092
# Epoch 21/50
# 130/130 [==============================] - 57s 440ms/step - loss: 0.1066 - accuracy: 0.9644 - val_loss: 0.3833 - val_accuracy: 0.8928
# Epoch 22/50
# 130/130 [==============================] - 1329s 10s/step - loss: 0.1000 - accuracy: 0.9671 - val_loss: 0.1831 - val_accuracy: 0.9411
# Epoch 23/50
# 130/130 [==============================] - 50s 385ms/step - loss: 0.0798 - accuracy: 0.9704 - val_loss: 0.1936 - val_accuracy: 0.9449
# Epoch 24/50
# 130/130 [==============================] - 57s 438ms/step - loss: 0.0675 - accuracy: 0.9762 - val_loss: 0.2080 - val_accuracy: 0.9372
# Epoch 25/50
# 130/130 [==============================] - 57s 439ms/step - loss: 0.0790 - accuracy: 0.9686 - val_loss: 0.2186 - val_accuracy: 0.9314
# Epoch 26/50
# 130/130 [==============================] - 58s 444ms/step - loss: 0.0775 - accuracy: 0.9762 - val_loss: 0.2371 - val_accuracy: 0.9382
# Epoch 27/50
# 130/130 [==============================] - 58s 447ms/step - loss: 0.0772 - accuracy: 0.9717 - val_loss: 0.2025 - val_accuracy: 0.9469
# Epoch 28/50
# 130/130 [==============================] - 58s 445ms/step - loss: 0.1008 - accuracy: 0.9640 - val_loss: 0.1487 - val_accuracy: 0.9556
# Epoch 29/50
# 130/130 [==============================] - 57s 440ms/step - loss: 0.0731 - accuracy: 0.9754 - val_loss: 0.1908 - val_accuracy: 0.9430
# Epoch 30/50
# 130/130 [==============================] - 56s 434ms/step - loss: 0.0517 - accuracy: 0.9874 - val_loss: 0.2203 - val_accuracy: 0.9459
# Epoch 31/50
# 130/130 [==============================] - 57s 436ms/step - loss: 0.0769 - accuracy: 0.9736 - val_loss: 0.1793 - val_accuracy: 0.9488
# Epoch 32/50
# 130/130 [==============================] - 58s 448ms/step - loss: 0.0494 - accuracy: 0.9839 - val_loss: 0.2116 - val_accuracy: 0.9430
# Epoch 33/50
# 130/130 [==============================] - 2755s 21s/step - loss: 0.0867 - accuracy: 0.9691 - val_loss: 0.2414 - val_accuracy: 0.9372
# Epoch 34/50
# 130/130 [==============================] - 49s 381ms/step - loss: 0.0676 - accuracy: 0.9768 - val_loss: 0.2083 - val_accuracy: 0.9391
# Epoch 35/50
# 130/130 [==============================] - 57s 437ms/step - loss: 0.0578 - accuracy: 0.9829 - val_loss: 0.3369 - val_accuracy: 0.9237
# Epoch 36/50
# 130/130 [==============================] - 57s 439ms/step - loss: 0.0703 - accuracy: 0.9766 - val_loss: 0.1725 - val_accuracy: 0.9565
# Epoch 37/50
# 130/130 [==============================] - 57s 437ms/step - loss: 0.0568 - accuracy: 0.9795 - val_loss: 0.2086 - val_accuracy: 0.9449
# Epoch 38/50
# 130/130 [==============================] - 58s 445ms/step - loss: 0.0382 - accuracy: 0.9879 - val_loss: 0.1401 - val_accuracy: 0.9623
# Epoch 39/50
# 130/130 [==============================] - 57s 441ms/step - loss: 0.0524 - accuracy: 0.9797 - val_loss: 0.1842 - val_accuracy: 0.9556
# Epoch 40/50
# 130/130 [==============================] - 57s 437ms/step - loss: 0.0558 - accuracy: 0.9825 - val_loss: 0.2095 - val_accuracy: 0.9556
# Epoch 41/50
# 130/130 [==============================] - 56s 435ms/step - loss: 0.0393 - accuracy: 0.9875 - val_loss: 0.2679 - val_accuracy: 0.9324
# Epoch 42/50
# 130/130 [==============================] - 56s 434ms/step - loss: 0.0693 - accuracy: 0.9796 - val_loss: 0.1844 - val_accuracy: 0.9449
# Epoch 43/50
# 130/130 [==============================] - 57s 442ms/step - loss: 0.0465 - accuracy: 0.9829 - val_loss: 0.1527 - val_accuracy: 0.9556
# Epoch 44/50
# 130/130 [==============================] - 4385s 34s/step - loss: 0.0686 - accuracy: 0.9801 - val_loss: 0.1659 - val_accuracy: 0.9565
# Epoch 45/50
# 130/130 [==============================] - 43s 334ms/step - loss: 0.0355 - accuracy: 0.9893 - val_loss: 0.1535 - val_accuracy: 0.9662
# Epoch 46/50
# 130/130 [==============================] - 44s 335ms/step - loss: 0.0298 - accuracy: 0.9883 - val_loss: 0.2105 - val_accuracy: 0.9536
# Epoch 47/50
# 130/130 [==============================] - 43s 330ms/step - loss: 0.0216 - accuracy: 0.9924 - val_loss: 0.1021 - val_accuracy: 0.9720
# Epoch 48/50
# 130/130 [==============================] - 41s 312ms/step - loss: 0.0302 - accuracy: 0.9893 - val_loss: 0.3761 - val_accuracy: 0.9150
# Epoch 49/50
# 130/130 [==============================] - 40s 311ms/step - loss: 0.1080 - accuracy: 0.9650 - val_loss: 0.3282 - val_accuracy: 0.9198
# Epoch 50/50
# 130/130 [==============================] - 41s 318ms/step - loss: 0.0494 - accuracy: 0.9837 - val_loss: 0.1653 - val_accuracy: 0.9585

# %% [markdown]
# ## Visualize training results
#
# After applying data augmentation and Dropout, there is less overfitting than before, and training and validation accuracy are closer aligned.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Saving Model

# %%
model.save_weights('my_checkpoint.ckpt')

# %% [markdown]
# ## Predict on new data

# %% [markdown]
# Note: Data augmentation and Dropout layers are inactive at inference time.

# %%
test_image_path = "bac_spot.jpg"

img = keras.preprocessing.image.load_img(
    test_image_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path)
# Out:
# This image most likely belongs to Tomato_Bacterial_Spot with a 99.95 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
test_image_path2 = "erly_blight.jpg"

img = keras.preprocessing.image.load_img(
    test_image_path2, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path2)
# Out:
# This image most likely belongs to Tomato_Early_Blight with a 99.52 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
test_image_path2 = "healthy.jpg"

img = keras.preprocessing.image.load_img(
    test_image_path2, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path2)
# Out:
# This image most likely belongs to Tomato_Healthy with a 99.61 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
test_image_path2 = "leaf_mold.jpg" #erly_blight.jpg" #"

img = keras.preprocessing.image.load_img(
    test_image_path2, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path2)
# Out:
# This image most likely belongs to Tomato_Leaf_mold with a 96.19 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
test_image_path2 = "septorial_leaf_spot.jpg"

img = keras.preprocessing.image.load_img(
    test_image_path2, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path2)
# Out:
# This image most likely belongs to Tomato_Septorial_Leaf_Spot with a 61.54 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>

# %%
test_image_path2 = "yellow_leaf_curl_virus.jpg"

img = keras.preprocessing.image.load_img(
    test_image_path2, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
PIL.Image.open(test_image_path2)
# Out:
# This image most likely belongs to Tomato_Yellow_Leaf_Curl_Virus with a 100.00 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>
